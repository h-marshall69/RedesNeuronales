# %% [markdown]
# <a href="https://colab.research.google.com/github/h-marshall69/NilvelLagoPuno/blob/main/RecopilacionDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Montaje de Google Drive
from google.colab import drive
import os

# Montaje de Google Drive
drive.mount('/content/drive')

# Configuración de la carpeta de guardado
path_dir = '/content/drive/MyDrive/LagoPuno'
os.makedirs(path_dir, exist_ok=True)
os.chdir(path_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import concurrent.futures
import time
import os

url = "https://www.senamhi.gob.pe/include/ajax-informacion-diaria.php"
headers = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Content-Type': 'application/x-www-form-urlencoded',
    'User-Agent': 'Mozilla/5.0',
}

def filtrar_datos(data, estaciones):
    return [entry for entry in data['content'] if entry['nomEsta'] in estaciones]

def obtener_datos(fecha, hora, estaciones):
    fecha_str = fecha.strftime('%Y-%m-%d')
    data = {
        'fecha': fecha_str,
        'hora': hora
    }

    try:
        response = requests.post(url, headers=headers, data=data)
        response.raise_for_status()
        datos_filtrados = filtrar_datos(response.json(), estaciones)
        return fecha_str, datos_filtrados
    except requests.exceptions.RequestException as e:
        print(f"Error en la solicitud para {fecha_str}: {e}")
        return fecha_str, None

def reintentar_fechas_fallidas(fechas_fallidas, hora, estaciones, datos_recolectados):
    print(f"Reintentando {len(fechas_fallidas)} fechas fallidas...")
    for fecha in fechas_fallidas:
        fecha_str, resultado = obtener_datos(fecha, hora, estaciones)
        if resultado:
            datos_recolectados.extend([{
                'fecha': fecha_str,
                'codZonal': dato['codZonal'],
                'codEsta': dato['codEsta'],
                'nomEsta': dato['nomEsta'],
                'uniHidrografica': dato['uniHidrografica'],
                'nomDepa': dato['nomDepa'],
                'nomCuenca': dato['nomCuenca'],
                'nomSector': dato['nomSector'],
                'dato': dato['dato'],
                'unidad': dato['unidad'],
                'datAnomalia': dato['datAnomalia'],
                'uniAnomalia': dato['uniAnomalia'],
                'tendencia': dato['tendencia'],
                'umbralRojo': dato['umbralRojo'],
                'cuerpoAgua': dato['cuerpoAgua']
            } for dato in resultado])

def main():
    estaciones = ['MUELLE ENAFER']  # Añade aquí las estaciones que quieras monitorear
    fecha_inicio = datetime(2023, 10, 13)
    fecha_fin = datetime(2024, 10, 13)
    hora = '18:00'

    fechas = [fecha_inicio + timedelta(days=i) for i in range((fecha_fin - fecha_inicio).days + 1)]
    datos_recolectados = []
    fechas_fallidas = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        futuro_a_fecha = {executor.submit(obtener_datos, fecha, hora, estaciones): fecha for fecha in fechas}
        for futuro in concurrent.futures.as_completed(futuro_a_fecha):
            fecha = futuro_a_fecha[futuro]
            fecha_str, resultado = futuro.result()
            if resultado:
                datos_recolectados.extend([{
                    'fecha': fecha_str,
                    'codZonal': dato['codZonal'],
                    'codEsta': dato['codEsta'],
                    'nomEsta': dato['nomEsta'],
                    'uniHidrografica': dato['uniHidrografica'],
                    'nomDepa': dato['nomDepa'],
                    'nomCuenca': dato['nomCuenca'],
                    'nomSector': dato['nomSector'],
                    'dato': dato['dato'],
                    'unidad': dato['unidad'],
                    'datAnomalia': dato['datAnomalia'],
                    'uniAnomalia': dato['uniAnomalia'],
                    'tendencia': dato['tendencia'],
                    'umbralRojo': dato['umbralRojo'],
                    'cuerpoAgua': dato['cuerpoAgua']
                } for dato in resultado])
            else:
                fechas_fallidas.append(fecha)  # Almacenar fechas con errores

            porcentaje_recolectados = (len(datos_recolectados) / (len(fechas) * len(estaciones))) * 100
            print(f"Datos recolectados: {len(datos_recolectados)} de {len(fechas) * len(estaciones)} posibles ({porcentaje_recolectados:.2f}%).")

    # Reintentar las fechas que dieron error
    reintentar_fechas_fallidas(fechas_fallidas, hora, estaciones, datos_recolectados)

    # Crear DataFrame y ordenar por fecha
    df = pd.DataFrame(datos_recolectados)
    df['fecha'] = pd.to_datetime(df['fecha'])  # Convertir 'fecha' a datetime
    df = df.sort_values('fecha')  # Ordenar por fecha

    csv_filename = os.path.join(path_dir, 'datos_estaciones_2024.csv')
    df.to_csv(csv_filename, index=False)
    print(f"Datos guardados en '{csv_filename}'.")

if __name__ == "__main__":
    main()
# Out:
# Datos recolectados: 25 de 367 posibles (6.81%).
# Datos recolectados: 26 de 367 posibles (7.08%).
# Datos recolectados: 27 de 367 posibles (7.36%).
# Datos recolectados: 28 de 367 posibles (7.63%).
# Datos recolectados: 29 de 367 posibles (7.90%).
# Datos recolectados: 30 de 367 posibles (8.17%).
# Datos recolectados: 31 de 367 posibles (8.45%).
# Datos recolectados: 32 de 367 posibles (8.72%).
# Datos recolectados: 33 de 367 posibles (8.99%).
# Error en la solicitud para 2023-11-19: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 33 de 367 posibles (8.99%).
# Datos recolectados: 34 de 367 posibles (9.26%).
# Datos recolectados: 35 de 367 posibles (9.54%).
# Datos recolectados: 36 de 367 posibles (9.81%).
# Datos recolectados: 37 de 367 posibles (10.08%).
# Datos recolectados: 38 de 367 posibles (10.35%).
# Datos recolectados: 39 de 367 posibles (10.63%).
# Datos recolectados: 40 de 367 posibles (10.90%).
# Datos recolectados: 41 de 367 posibles (11.17%).
# Datos recolectados: 42 de 367 posibles (11.44%).
# Datos recolectados: 43 de 367 posibles (11.72%).
# Datos recolectados: 44 de 367 posibles (11.99%).
# Datos recolectados: 45 de 367 posibles (12.26%).
# Datos recolectados: 46 de 367 posibles (12.53%).
# Datos recolectados: 47 de 367 posibles (12.81%).
# Datos recolectados: 48 de 367 posibles (13.08%).
# Datos recolectados: 49 de 367 posibles (13.35%).
# Datos recolectados: 50 de 367 posibles (13.62%).
# Datos recolectados: 51 de 367 posibles (13.90%).
# Datos recolectados: 52 de 367 posibles (14.17%).
# Datos recolectados: 53 de 367 posibles (14.44%).
# Datos recolectados: 54 de 367 posibles (14.71%).
# Datos recolectados: 55 de 367 posibles (14.99%).
# Datos recolectados: 56 de 367 posibles (15.26%).
# Datos recolectados: 57 de 367 posibles (15.53%).
# Datos recolectados: 58 de 367 posibles (15.80%).
# Datos recolectados: 59 de 367 posibles (16.08%).
# Datos recolectados: 60 de 367 posibles (16.35%).
# Datos recolectados: 61 de 367 posibles (16.62%).
# Datos recolectados: 62 de 367 posibles (16.89%).
# Datos recolectados: 63 de 367 posibles (17.17%).
# Datos recolectados: 64 de 367 posibles (17.44%).
# Datos recolectados: 65 de 367 posibles (17.71%).
# Datos recolectados: 66 de 367 posibles (17.98%).
# Datos recolectados: 67 de 367 posibles (18.26%).
# Datos recolectados: 68 de 367 posibles (18.53%).
# Datos recolectados: 69 de 367 posibles (18.80%).
# Datos recolectados: 70 de 367 posibles (19.07%).
# Datos recolectados: 71 de 367 posibles (19.35%).
# Datos recolectados: 72 de 367 posibles (19.62%).
# Datos recolectados: 73 de 367 posibles (19.89%).
# Datos recolectados: 74 de 367 posibles (20.16%).
# Datos recolectados: 75 de 367 posibles (20.44%).
# Datos recolectados: 76 de 367 posibles (20.71%).
# Error en la solicitud para 2024-01-05: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 76 de 367 posibles (20.71%).
# Datos recolectados: 77 de 367 posibles (20.98%).
# Datos recolectados: 78 de 367 posibles (21.25%).
# Datos recolectados: 79 de 367 posibles (21.53%).
# Error en la solicitud para 2024-01-08: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 79 de 367 posibles (21.53%).
# Datos recolectados: 80 de 367 posibles (21.80%).
# Datos recolectados: 81 de 367 posibles (22.07%).
# Datos recolectados: 82 de 367 posibles (22.34%).
# Datos recolectados: 83 de 367 posibles (22.62%).
# Datos recolectados: 84 de 367 posibles (22.89%).
# Datos recolectados: 85 de 367 posibles (23.16%).
# Datos recolectados: 86 de 367 posibles (23.43%).
# Datos recolectados: 87 de 367 posibles (23.71%).
# Datos recolectados: 88 de 367 posibles (23.98%).
# Datos recolectados: 89 de 367 posibles (24.25%).
# Datos recolectados: 90 de 367 posibles (24.52%).
# Error en la solicitud para 2024-01-19: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 90 de 367 posibles (24.52%).
# Datos recolectados: 91 de 367 posibles (24.80%).
# Datos recolectados: 92 de 367 posibles (25.07%).
# Datos recolectados: 93 de 367 posibles (25.34%).
# Datos recolectados: 94 de 367 posibles (25.61%).
# Datos recolectados: 95 de 367 posibles (25.89%).
# Datos recolectados: 96 de 367 posibles (26.16%).
# Datos recolectados: 97 de 367 posibles (26.43%).
# Datos recolectados: 98 de 367 posibles (26.70%).
# Datos recolectados: 99 de 367 posibles (26.98%).
# Datos recolectados: 100 de 367 posibles (27.25%).
# Error en la solicitud para 2024-01-31: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 100 de 367 posibles (27.25%).
# Datos recolectados: 101 de 367 posibles (27.52%).
# Datos recolectados: 102 de 367 posibles (27.79%).
# Datos recolectados: 103 de 367 posibles (28.07%).
# Datos recolectados: 104 de 367 posibles (28.34%).
# Datos recolectados: 105 de 367 posibles (28.61%).
# Datos recolectados: 106 de 367 posibles (28.88%).
# Datos recolectados: 107 de 367 posibles (29.16%).
# Datos recolectados: 108 de 367 posibles (29.43%).
# Datos recolectados: 109 de 367 posibles (29.70%).
# Datos recolectados: 110 de 367 posibles (29.97%).
# Datos recolectados: 111 de 367 posibles (30.25%).
# Datos recolectados: 112 de 367 posibles (30.52%).
# Datos recolectados: 113 de 367 posibles (30.79%).
# Datos recolectados: 114 de 367 posibles (31.06%).
# Datos recolectados: 115 de 367 posibles (31.34%).
# Datos recolectados: 116 de 367 posibles (31.61%).
# Datos recolectados: 117 de 367 posibles (31.88%).
# Datos recolectados: 118 de 367 posibles (32.15%).
# Datos recolectados: 119 de 367 posibles (32.43%).
# Datos recolectados: 120 de 367 posibles (32.70%).
# Datos recolectados: 121 de 367 posibles (32.97%).
# Datos recolectados: 122 de 367 posibles (33.24%).
# Datos recolectados: 123 de 367 posibles (33.51%).
# Datos recolectados: 124 de 367 posibles (33.79%).
# Datos recolectados: 125 de 367 posibles (34.06%).
# Datos recolectados: 126 de 367 posibles (34.33%).
# Datos recolectados: 127 de 367 posibles (34.60%).
# Datos recolectados: 128 de 367 posibles (34.88%).
# Datos recolectados: 129 de 367 posibles (35.15%).
# Datos recolectados: 130 de 367 posibles (35.42%).
# Datos recolectados: 131 de 367 posibles (35.69%).
# Datos recolectados: 132 de 367 posibles (35.97%).
# Datos recolectados: 133 de 367 posibles (36.24%).
# Datos recolectados: 134 de 367 posibles (36.51%).
# Datos recolectados: 135 de 367 posibles (36.78%).
# Datos recolectados: 136 de 367 posibles (37.06%).
# Datos recolectados: 137 de 367 posibles (37.33%).
# Datos recolectados: 138 de 367 posibles (37.60%).
# Datos recolectados: 139 de 367 posibles (37.87%).
# Datos recolectados: 140 de 367 posibles (38.15%).
# Datos recolectados: 141 de 367 posibles (38.42%).
# Datos recolectados: 142 de 367 posibles (38.69%).
# Datos recolectados: 143 de 367 posibles (38.96%).
# Datos recolectados: 144 de 367 posibles (39.24%).
# Datos recolectados: 145 de 367 posibles (39.51%).
# Datos recolectados: 146 de 367 posibles (39.78%).
# Datos recolectados: 147 de 367 posibles (40.05%).
# Datos recolectados: 148 de 367 posibles (40.33%).
# Datos recolectados: 149 de 367 posibles (40.60%).
# Datos recolectados: 150 de 367 posibles (40.87%).
# Datos recolectados: 151 de 367 posibles (41.14%).
# Datos recolectados: 152 de 367 posibles (41.42%).
# Datos recolectados: 153 de 367 posibles (41.69%).
# Datos recolectados: 154 de 367 posibles (41.96%).
# Datos recolectados: 155 de 367 posibles (42.23%).
# Datos recolectados: 156 de 367 posibles (42.51%).
# Datos recolectados: 157 de 367 posibles (42.78%).
# Datos recolectados: 158 de 367 posibles (43.05%).
# Datos recolectados: 159 de 367 posibles (43.32%).
# Datos recolectados: 160 de 367 posibles (43.60%).
# Datos recolectados: 161 de 367 posibles (43.87%).
# Datos recolectados: 162 de 367 posibles (44.14%).
# Datos recolectados: 163 de 367 posibles (44.41%).
# Datos recolectados: 164 de 367 posibles (44.69%).
# Datos recolectados: 165 de 367 posibles (44.96%).
# Datos recolectados: 166 de 367 posibles (45.23%).
# Datos recolectados: 167 de 367 posibles (45.50%).
# Datos recolectados: 168 de 367 posibles (45.78%).
# Datos recolectados: 169 de 367 posibles (46.05%).
# Datos recolectados: 170 de 367 posibles (46.32%).
# Datos recolectados: 171 de 367 posibles (46.59%).
# Datos recolectados: 172 de 367 posibles (46.87%).
# Datos recolectados: 173 de 367 posibles (47.14%).
# Datos recolectados: 174 de 367 posibles (47.41%).
# Datos recolectados: 175 de 367 posibles (47.68%).
# Datos recolectados: 176 de 367 posibles (47.96%).
# Error en la solicitud para 2024-04-17: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 176 de 367 posibles (47.96%).
# Datos recolectados: 177 de 367 posibles (48.23%).
# Datos recolectados: 178 de 367 posibles (48.50%).
# Datos recolectados: 179 de 367 posibles (48.77%).
# Datos recolectados: 180 de 367 posibles (49.05%).
# Datos recolectados: 181 de 367 posibles (49.32%).
# Datos recolectados: 182 de 367 posibles (49.59%).
# Datos recolectados: 183 de 367 posibles (49.86%).
# Datos recolectados: 184 de 367 posibles (50.14%).
# Datos recolectados: 185 de 367 posibles (50.41%).
# Datos recolectados: 186 de 367 posibles (50.68%).
# Datos recolectados: 187 de 367 posibles (50.95%).
# Datos recolectados: 188 de 367 posibles (51.23%).
# Datos recolectados: 189 de 367 posibles (51.50%).
# Datos recolectados: 190 de 367 posibles (51.77%).
# Datos recolectados: 191 de 367 posibles (52.04%).
# Datos recolectados: 192 de 367 posibles (52.32%).
# Datos recolectados: 193 de 367 posibles (52.59%).
# Datos recolectados: 194 de 367 posibles (52.86%).
# Datos recolectados: 195 de 367 posibles (53.13%).
# Datos recolectados: 196 de 367 posibles (53.41%).
# Datos recolectados: 197 de 367 posibles (53.68%).
# Datos recolectados: 198 de 367 posibles (53.95%).
# Datos recolectados: 199 de 367 posibles (54.22%).
# Datos recolectados: 200 de 367 posibles (54.50%).
# Datos recolectados: 201 de 367 posibles (54.77%).
# Datos recolectados: 202 de 367 posibles (55.04%).
# Datos recolectados: 203 de 367 posibles (55.31%).
# Datos recolectados: 204 de 367 posibles (55.59%).
# Datos recolectados: 205 de 367 posibles (55.86%).
# Datos recolectados: 206 de 367 posibles (56.13%).
# Datos recolectados: 207 de 367 posibles (56.40%).
# Datos recolectados: 208 de 367 posibles (56.68%).
# Datos recolectados: 209 de 367 posibles (56.95%).
# Datos recolectados: 210 de 367 posibles (57.22%).
# Datos recolectados: 211 de 367 posibles (57.49%).
# Datos recolectados: 212 de 367 posibles (57.77%).
# Datos recolectados: 213 de 367 posibles (58.04%).
# Datos recolectados: 214 de 367 posibles (58.31%).
# Datos recolectados: 215 de 367 posibles (58.58%).
# Datos recolectados: 216 de 367 posibles (58.86%).
# Datos recolectados: 217 de 367 posibles (59.13%).
# Datos recolectados: 218 de 367 posibles (59.40%).
# Datos recolectados: 219 de 367 posibles (59.67%).
# Datos recolectados: 220 de 367 posibles (59.95%).
# Datos recolectados: 221 de 367 posibles (60.22%).
# Datos recolectados: 222 de 367 posibles (60.49%).
# Datos recolectados: 223 de 367 posibles (60.76%).
# Datos recolectados: 224 de 367 posibles (61.04%).
# Datos recolectados: 225 de 367 posibles (61.31%).
# Datos recolectados: 226 de 367 posibles (61.58%).
# Datos recolectados: 227 de 367 posibles (61.85%).
# Datos recolectados: 228 de 367 posibles (62.13%).
# Datos recolectados: 229 de 367 posibles (62.40%).
# Datos recolectados: 230 de 367 posibles (62.67%).
# Datos recolectados: 231 de 367 posibles (62.94%).
# Datos recolectados: 232 de 367 posibles (63.22%).
# Datos recolectados: 233 de 367 posibles (63.49%).
# Datos recolectados: 234 de 367 posibles (63.76%).
# Datos recolectados: 235 de 367 posibles (64.03%).
# Datos recolectados: 236 de 367 posibles (64.31%).
# Datos recolectados: 237 de 367 posibles (64.58%).
# Datos recolectados: 238 de 367 posibles (64.85%).
# Error en la solicitud para 2024-06-17: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 238 de 367 posibles (64.85%).
# Datos recolectados: 238 de 367 posibles (64.85%).
# Error en la solicitud para 2024-06-18: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 238 de 367 posibles (64.85%).
# Datos recolectados: 239 de 367 posibles (65.12%).
# Datos recolectados: 239 de 367 posibles (65.12%).
# Datos recolectados: 240 de 367 posibles (65.40%).
# Datos recolectados: 241 de 367 posibles (65.67%).
# Datos recolectados: 242 de 367 posibles (65.94%).
# Datos recolectados: 243 de 367 posibles (66.21%).
# Datos recolectados: 244 de 367 posibles (66.49%).
# Datos recolectados: 245 de 367 posibles (66.76%).
# Datos recolectados: 246 de 367 posibles (67.03%).
# Datos recolectados: 247 de 367 posibles (67.30%).
# Datos recolectados: 248 de 367 posibles (67.57%).
# Datos recolectados: 249 de 367 posibles (67.85%).
# Datos recolectados: 250 de 367 posibles (68.12%).
# Datos recolectados: 251 de 367 posibles (68.39%).
# Datos recolectados: 252 de 367 posibles (68.66%).
# Datos recolectados: 253 de 367 posibles (68.94%).
# Datos recolectados: 254 de 367 posibles (69.21%).
# Datos recolectados: 255 de 367 posibles (69.48%).
# Datos recolectados: 256 de 367 posibles (69.75%).
# Datos recolectados: 257 de 367 posibles (70.03%).
# Datos recolectados: 258 de 367 posibles (70.30%).
# Datos recolectados: 259 de 367 posibles (70.57%).
# Error en la solicitud para 2024-07-12: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 259 de 367 posibles (70.57%).
# Datos recolectados: 260 de 367 posibles (70.84%).
# Datos recolectados: 261 de 367 posibles (71.12%).
# Datos recolectados: 262 de 367 posibles (71.39%).
# Datos recolectados: 263 de 367 posibles (71.66%).
# Datos recolectados: 264 de 367 posibles (71.93%).
# Datos recolectados: 265 de 367 posibles (72.21%).
# Datos recolectados: 266 de 367 posibles (72.48%).
# Datos recolectados: 267 de 367 posibles (72.75%).
# Datos recolectados: 268 de 367 posibles (73.02%).
# Datos recolectados: 269 de 367 posibles (73.30%).
# Datos recolectados: 270 de 367 posibles (73.57%).
# Datos recolectados: 271 de 367 posibles (73.84%).
# Datos recolectados: 272 de 367 posibles (74.11%).
# Datos recolectados: 273 de 367 posibles (74.39%).
# Datos recolectados: 274 de 367 posibles (74.66%).
# Datos recolectados: 275 de 367 posibles (74.93%).
# Datos recolectados: 276 de 367 posibles (75.20%).
# Datos recolectados: 277 de 367 posibles (75.48%).
# Datos recolectados: 278 de 367 posibles (75.75%).
# Datos recolectados: 279 de 367 posibles (76.02%).
# Error en la solicitud para 2024-08-03: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 279 de 367 posibles (76.02%).
# Datos recolectados: 280 de 367 posibles (76.29%).
# Error en la solicitud para 2024-08-06: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 280 de 367 posibles (76.29%).
# Datos recolectados: 281 de 367 posibles (76.57%).
# Datos recolectados: 281 de 367 posibles (76.57%).
# Datos recolectados: 282 de 367 posibles (76.84%).
# Datos recolectados: 283 de 367 posibles (77.11%).
# Datos recolectados: 284 de 367 posibles (77.38%).
# Datos recolectados: 285 de 367 posibles (77.66%).
# Datos recolectados: 286 de 367 posibles (77.93%).
# Datos recolectados: 287 de 367 posibles (78.20%).
# Datos recolectados: 288 de 367 posibles (78.47%).
# Datos recolectados: 289 de 367 posibles (78.75%).
# Datos recolectados: 290 de 367 posibles (79.02%).
# Datos recolectados: 291 de 367 posibles (79.29%).
# Datos recolectados: 292 de 367 posibles (79.56%).
# Datos recolectados: 293 de 367 posibles (79.84%).
# Datos recolectados: 294 de 367 posibles (80.11%).
# Datos recolectados: 295 de 367 posibles (80.38%).
# Datos recolectados: 296 de 367 posibles (80.65%).
# Datos recolectados: 297 de 367 posibles (80.93%).
# Datos recolectados: 298 de 367 posibles (81.20%).
# Datos recolectados: 299 de 367 posibles (81.47%).
# Datos recolectados: 300 de 367 posibles (81.74%).
# Datos recolectados: 301 de 367 posibles (82.02%).
# Datos recolectados: 302 de 367 posibles (82.29%).
# Datos recolectados: 303 de 367 posibles (82.56%).
# Datos recolectados: 304 de 367 posibles (82.83%).
# Datos recolectados: 305 de 367 posibles (83.11%).
# Datos recolectados: 306 de 367 posibles (83.38%).
# Error en la solicitud para 2024-09-03: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 306 de 367 posibles (83.38%).
# Datos recolectados: 307 de 367 posibles (83.65%).
# Error en la solicitud para 2024-09-07: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 307 de 367 posibles (83.65%).
# Datos recolectados: 309 de 367 posibles (84.20%).
# Datos recolectados: 310 de 367 posibles (84.47%).
# Datos recolectados: 311 de 367 posibles (84.74%).
# Datos recolectados: 312 de 367 posibles (85.01%).
# Datos recolectados: 313 de 367 posibles (85.29%).
# Datos recolectados: 314 de 367 posibles (85.56%).
# Datos recolectados: 315 de 367 posibles (85.83%).
# Datos recolectados: 316 de 367 posibles (86.10%).
# Datos recolectados: 317 de 367 posibles (86.38%).
# Datos recolectados: 318 de 367 posibles (86.65%).
# Datos recolectados: 319 de 367 posibles (86.92%).
# Datos recolectados: 320 de 367 posibles (87.19%).
# Datos recolectados: 321 de 367 posibles (87.47%).
# Error en la solicitud para 2024-09-17: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 321 de 367 posibles (87.47%).
# Datos recolectados: 322 de 367 posibles (87.74%).
# Datos recolectados: 323 de 367 posibles (88.01%).
# Datos recolectados: 324 de 367 posibles (88.28%).
# Datos recolectados: 325 de 367 posibles (88.56%).
# Datos recolectados: 326 de 367 posibles (88.83%).
# Datos recolectados: 327 de 367 posibles (89.10%).
# Datos recolectados: 328 de 367 posibles (89.37%).
# Error en la solicitud para 2024-09-27: Expecting value: line 1 column 1 (char 0)
# Datos recolectados: 328 de 367 posibles (89.37%).
# Datos recolectados: 329 de 367 posibles (89.65%).
# Datos recolectados: 330 de 367 posibles (89.92%).
# Datos recolectados: 332 de 367 posibles (90.46%).
# Datos recolectados: 333 de 367 posibles (90.74%).
# Datos recolectados: 334 de 367 posibles (91.01%).
# Datos recolectados: 335 de 367 posibles (91.28%).
# Datos recolectados: 336 de 367 posibles (91.55%).
# Datos recolectados: 337 de 367 posibles (91.83%).
# Datos recolectados: 338 de 367 posibles (92.10%).
# Datos recolectados: 339 de 367 posibles (92.37%).
# Datos recolectados: 340 de 367 posibles (92.64%).
# Datos recolectados: 341 de 367 posibles (92.92%).
# Datos recolectados: 342 de 367 posibles (93.19%).
# Datos recolectados: 343 de 367 posibles (93.46%).
# Datos recolectados: 344 de 367 posibles (93.73%).
# Datos recolectados: 345 de 367 posibles (94.01%).
# Datos recolectados: 346 de 367 posibles (94.28%).
# Datos recolectados: 347 de 367 posibles (94.55%).
# Reintentando 22 fechas fallidas...
# Datos guardados en '/content/drive/MyDrive/LagoPuno/datos_estaciones_2024.csv'.

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import concurrent.futures
import logging
import time
import json
import os

# Configuración de logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

url = "https://www.senamhi.gob.pe/include/ajax-informacion-mensual.php"
headers = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Content-Type': 'application/x-www-form-urlencoded',
    'User-Agent': 'Mozilla/5.0',
}

def filtrar_datos(data, estaciones):
    try:
        return [entry for entry in data['content'][0]['detalle'] if entry['nomEsta'] in estaciones]
    except (KeyError, IndexError, TypeError) as e:
        logging.error(f"Error al filtrar datos: {e}")
        return []

def obtener_datos_mensuales(fecha, estaciones, max_retries=3):
    data = {
        'fecha': fecha.strftime('%Y-%m'),
    }

    for attempt in range(max_retries):
        try:
            response = requests.post(url, headers=headers, data=data, timeout=10)
            response.raise_for_status()
            json_data = response.json()
            datos_filtrados = filtrar_datos(json_data, estaciones)
            return fecha.strftime('%Y-%m'), datos_filtrados
        except requests.exceptions.RequestException as e:
            logging.warning(f"Intento {attempt + 1} fallido para {fecha.strftime('%Y-%m')}: {e}")
            if attempt < max_retries - 1:
                time.sleep(2 ** attempt)  # Espera exponencial entre intentos
            else:
                logging.error(f"Error en la solicitud para {fecha.strftime('%Y-%m')} después de {max_retries} intentos: {e}")
        except json.JSONDecodeError as e:
            logging.error(f"Error al decodificar JSON para {fecha.strftime('%Y-%m')}: {e}")
            break  # Si hay un error de JSON, no tiene sentido reintentar

    return fecha.strftime('%Y-%m'), None

def reintentar_fechas_fallidas(fechas_fallidas, estaciones, datos_recolectados):
    logging.info(f"Reintentando {len(fechas_fallidas)} fechas fallidas...")
    for fecha in fechas_fallidas:
        fecha_str, resultado = obtener_datos_mensuales(fecha, estaciones)
        if resultado:
            datos_recolectados.extend([{
                'fecha': fecha_str,
                'codZonal': dato.get('codZonal', ''),
                'codEsta': dato.get('codEsta', ''),
                'nomEsta': dato.get('nomEsta', ''),
                'uniHidrografica': dato.get('uniHidrografica', ''),
                'nomDepa': dato.get('nomDepa', ''),
                'nomSector': dato.get('nomSector', ''),
                'dato': dato.get('dato', ''),
                'datoAnt': dato.get('datoAnt', ''),
                'unidad': dato.get('unidad', ''),
                'datAnomalia': dato.get('datAnomalia', ''),
                'uniAnomalia': dato.get('uniAnomalia', ''),
                'tendencia': dato.get('tendencia', ''),
                'umbralRojo': dato.get('umbralRojo', ''),
                'cuerpoAgua': dato.get('cuerpoAgua', '')
            } for dato in resultado])

def main():
    estaciones = ['MUELLE ENAFER', 'OTRA ESTACION']
    fecha_inicio = datetime(1982, 10, 1)
    fecha_fin = datetime(2024, 9, 1)

    datos_recolectados = []
    fechas_fallidas = []
    fechas = []
    fecha_actual = fecha_inicio

    # Generar las fechas mensuales
    while fecha_actual <= fecha_fin:
        fechas.append(fecha_actual)
        fecha_actual += timedelta(days=32)
        fecha_actual = fecha_actual.replace(day=1)

    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        futuro_a_fecha = {executor.submit(obtener_datos_mensuales, fecha, estaciones): fecha for fecha in fechas}
        for futuro in concurrent.futures.as_completed(futuro_a_fecha):
            fecha = futuro_a_fecha[futuro]
            try:
                fecha_str, resultado = futuro.result()
                if resultado:
                    datos_recolectados.extend([{
                        'fecha': fecha_str,
                        'codZonal': dato.get('codZonal', ''),
                        'codEsta': dato.get('codEsta', ''),
                        'nomEsta': dato.get('nomEsta', ''),
                        'uniHidrografica': dato.get('uniHidrografica', ''),
                        'nomDepa': dato.get('nomDepa', ''),
                        'nomSector': dato.get('nomSector', ''),
                        'dato': dato.get('dato', ''),
                        'datoAnt': dato.get('datoAnt', ''),
                        'unidad': dato.get('unidad', ''),
                        'datAnomalia': dato.get('datAnomalia', ''),
                        'uniAnomalia': dato.get('uniAnomalia', ''),
                        'tendencia': dato.get('tendencia', ''),
                        'umbralRojo': dato.get('umbralRojo', ''),
                        'cuerpoAgua': dato.get('cuerpoAgua', '')
                    } for dato in resultado])
                else:
                    fechas_fallidas.append(fecha)  # Almacenar las fechas que fallaron
            except Exception as e:
                logging.error(f"Error al procesar los resultados para {fecha}: {e}")

    # Reintentar las fechas fallidas
    if fechas_fallidas:
        reintentar_fechas_fallidas(fechas_fallidas, estaciones, datos_recolectados)

    if datos_recolectados:
        # Crear DataFrame y ordenar por fecha
        df = pd.DataFrame(datos_recolectados)
        df['fecha'] = pd.to_datetime(df['fecha'])  # Convertir 'fecha' a datetime
        df = df.sort_values('fecha')  # Ordenar por fecha

        # Guardar en CSV
        csv_filename = os.path.join(path_dir, 'datos_mensuales_estaciones_2023-2024.csv')
        df.to_csv(csv_filename, index=False)
        logging.info(f"Datos guardados en '{csv_filename}'.")
    else:
        logging.warning("No se recolectaron datos. No se creará el archivo CSV.")

if __name__ == "__main__":
    main()
# Out:
# WARNING:root:Intento 1 fallido para 1985-09: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 1990-11: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 1992-07: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 1997-09: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 1999-04: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 1999-08: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2000-03: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2003-05: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2003-03: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2003-06: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2012-09: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2012-11: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2016-10: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2018-02: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 1 fallido para 2020-05: Expecting value: line 1 column 1 (char 0)
# WARNING:root:Intento 2 fallido para 2020-05: Expecting value: line 1 column 1 (char 0)
